# %%
from peptdeep.cli_argparse import convert_dict_to_argparse, global_settings

convert_dict_to_argparse(global_settings)
# Out:
# [('apd-model-frag_types', ['b', 'y', 'b_modloss', 'y_modloss']),
#  ('apd-model-max_frag_charge', 2),
#  ('apd-PEPTDEEP_HOME', '/Users/wenfengzeng/peptdeep'),
#  ('apd-local_model_zip_name', 'pretrained_models.zip'),
#  ('apd-model_url',
#   'https://github.com/MannLabs/alphapeptdeep/releases/download/pre-trained-models/pretrained_models.zip'),
#  ('apd-task_type', 'library'),
#  ('apd-task_type_choices', ['library', 'train', 'rescore']),
#  ('apd-thread_num', 16),
#  ('apd-torch_device-device_type', 'gpu'),
#  ('apd-torch_device-device_type_choices',
#   ['get_available', 'gpu', 'mps', 'cpu']),
#  ('apd-torch_device-device_ids', []),
#  ('apd-log_level', 'info'),
#  ('apd-log_level_choices', ['debug', 'info', 'warning', 'error', 'critical']),
#  ('apd-common-modloss_importance_level', 1.0),
#  ('apd-peak_matching-ms2_ppm', True),
#  ('apd-peak_matching-ms2_tol_value', 20.0),
#  ('apd-peak_matching-ms1_ppm', True),
#  ('apd-peak_matching-ms1_tol_value', 20.0),
# ...
